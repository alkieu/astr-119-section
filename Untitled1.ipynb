# %%
from astropy.io import fits
import numpy as np
import sep

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.patches import Ellipse

rcParams['figure.figsize'] = [10.,8.]

# %%
# read image into standard 2-d numpy array
data = fits.getdata("image.fits")
# Out:
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ESO-LOG 00:00:00> DATE         = '1992-10-26'  / Mon Oct 26, 1992                [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ESO-LOG 03:04:08>-START EXPO EMMI RED          / Start exp. on EMMI Red CC       [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ESO-LOG 03:04:09> EXPO EMMI RED NO = 24887     / Exp. num. on EMMI Red CCD       [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ESO-LOG 03:10:52>-STOP EXPO EMMI RED           / Stop exp. on EMMI Red CCD       [astropy.io.fits.card]

# %%
def image_analysis(image, thresh, bitswap=False):
    if bitswap:
        data = data.byteswap(inplace=False). newbyteorder()
        
# show the image
m, s = np.mean(data), np.std(data)
plt.imshow(data, interpolation='nearest', cmap='gray', vmin=m-s, vmax=m+s, origin='lower')
plt.colorbar();
plt.show("image 1")

# evaluate background as 2-d array, same size as original image
bkg_image = bkg.back()
# bkg_image = np.array(bkg) # equivalent to above
# show the background
plt.imshow(bkg_image, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()

# evaluate the background noise as 2-d array, same size as original image
bkg_rms = bkg.rms()
# show the background noise
plt.imshow(bkg_rms, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()
        
# subtract the background
data_sub = data - bkg        
objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
len(objects)

# plot background-subtracted image
fig, ax = plt.subplots()
m, s = np.mean(data_sub), np.std(data_sub)
im = ax.imshow(data_sub, interpolation='nearest', cmap='gray',
               vmin=m-s, vmax=m+s, origin='lower')

# plot an ellipse for each object
for i in range(len(objects)):
    e = Ellipse(xy=(objects['x'][i], objects['y'][i]),
                width=6*objects['a'][i],
                height=6*objects['b'][i],
                angle=objects['theta'][i] * 180. / np.pi)
    e.set_facecolor('none')
    e.set_edgecolor('red')
    ax.add_artist(e)

# %%
#background subtraction
# measure a spatially varying background on the image
bkg = sep.Background(data)
bkg = sep.Background(data, bw=64, bh=64, fw=3, fh=3)

# %%
# get a "global" mean and noise of the image background:
print(bkg.globalback)
print(bkg.globalrms)
# Out:
# 6852.04931640625
# 65.46174621582031

# %%
# available fields
objects.dtype.names
# Out:
# ('thresh',
#  'npix',
#  'tnpix',
#  'xmin',
#  'xmax',
#  'ymin',
#  'ymax',
#  'x',
#  'y',
#  'x2',
#  'y2',
#  'xy',
#  'errx2',
#  'erry2',
#  'errxy',
#  'a',
#  'b',
#  'theta',
#  'cxx',
#  'cyy',
#  'cxy',
#  'cflux',
#  'flux',
#  'cpeak',
#  'peak',
#  'xcpeak',
#  'ycpeak',
#  'xpeak',
#  'ypeak',
#  'flag')

# %% [markdown]
# ## Aperture photometry

# %%
flux, fluxerr, flag = sep.sum_circle(data_sub, objects['x'], objects['y'],
                                     3.0, err=bkg.globalrms, gain=1.0)

# %%
# show the first 10 objects results:
for i in range(10):
    print("object {:d}: flux = {:f} +/- {:f}".format(i, flux[i], fluxerr[i]))
# Out:
# object 0: flux = 2249.159297 +/- 291.027802
# object 1: flux = 3092.220430 +/- 291.592204
# object 2: flux = 5949.868379 +/- 356.562003
# object 3: flux = 1851.426582 +/- 295.028816
# object 4: flux = 72736.386914 +/- 440.172206
# object 5: flux = 3860.756152 +/- 352.163162
# object 6: flux = 6418.913789 +/- 357.458973
# object 7: flux = 2210.707656 +/- 350.791223
# object 8: flux = 2741.607227 +/- 352.277746
# object 9: flux = 20916.875566 +/- 376.966138

# %%
# read image into standard 2-d numpy array
data = fits.getdata("f105w.fits")

# %%
def image_analysis(image, thresh, bitswap=False):
    if bitswap:
        data = data.byteswap(inplace=True). newbyteorder()
        
# show the image
m, s = np.mean(data), np.std(data)
plt.imshow(data, interpolation='nearest', cmap='gray', vmin=m-s, vmax=m+s, origin='lower')
plt.colorbar();
plt.show("image 2")

# evaluate background as 2-d array, same size as original image
bkg_image = bkg.back()
# bkg_image = np.array(bkg) # equivalent to above
# show the background
plt.imshow(bkg_image, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()

# evaluate the background noise as 2-d array, same size as original image
bkg_rms = bkg.rms()
# show the background noise
plt.imshow(bkg_rms, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()
        
# subtract the background
data_sub = data - bkg 
bkg.subfrom(data)
objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
len(objects)

# plot background-subtracted image
fig, ax = plt.subplots()
m, s = np.mean(data_sub), np.std(data_sub)
im = ax.imshow(data_sub, interpolation='nearest', cmap='gray',
               vmin=m-s, vmax=m+s, origin='lower')

# plot an ellipse for each object
for i in range(len(objects)):
    e = Ellipse(xy=(objects['x'][i], objects['y'][i]),
                width=6*objects['a'][i],
                height=6*objects['b'][i],
                angle=objects['theta'][i] * 180. / np.pi)
    e.set_facecolor('none')
    e.set_edgecolor('green')
    ax.add_artist(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f995386c5f19> in <module>()
#      25
#      26 # subtract the background
# ---> 27 data_sub = data - bkg
#      28 bkg.subfrom(data)
#      29 objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
#
# ValueError: operands could not be broadcast together with shapes (3600,3600) (256,256)

# %%
# read image into standard 2-d numpy array
data = fits.getdata("f125w.fits")

# %%
def image_analysis(image, thresh, bitswap=False):
    if bitswap:
        data = data.byteswap(inplace=False). newbyteorder()
        
# show the image
m, s = np.mean(data), np.std(data)
plt.imshow(data, interpolation='nearest', cmap='gray', vmin=m-s, vmax=m+s, origin='lower')
plt.colorbar();
plt.show("image 3")

# evaluate background as 2-d array, same size as original image
bkg_image = bkg.back()
# bkg_image = np.array(bkg) # equivalent to above
# show the background
plt.imshow(bkg_image, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()

# evaluate the background noise as 2-d array, same size as original image
bkg_rms = bkg.rms()
# show the background noise
plt.imshow(bkg_rms, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()
        
# subtract the background
data_sub = data - bkg        
objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
len(objects)

# plot background-subtracted image
fig, ax = plt.subplots()
m, s = np.mean(data_sub), np.std(data_sub)
im = ax.imshow(data_sub, interpolation='nearest', cmap='gray',
               vmin=m-s, vmax=m+s, origin='lower')

# plot an ellipse for each object
for i in range(len(objects)):
    e = Ellipse(xy=(objects['x'][i], objects['y'][i]),
                width=6*objects['a'][i],
                height=6*objects['b'][i],
                angle=objects['theta'][i] * 180. / np.pi)
    e.set_facecolor('none')
    e.set_edgecolor('red')
    ax.add_artist(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-85a8d407cf5f> in <module>()
#      25
#      26 # subtract the background
# ---> 27 data_sub = data - bkg
#      28 objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
#      29 len(objects)
#
# ValueError: operands could not be broadcast together with shapes (3600,3600) (256,256)

# %%
# read image into standard 2-d numpy array
data = fits.getdata("f160w.fits")

# %%
def image_analysis(image, thresh, bitswap=False):
    if bitswap:
        data = data.byteswap(inplace=False). newbyteorder()
        
# show the image
m, s = np.mean(data), np.std(data)
plt.imshow(data, interpolation='nearest', cmap='gray', vmin=m-s, vmax=m+s, origin='lower')
plt.colorbar();
plt.show("image 4")

# evaluate background as 2-d array, same size as original image
bkg_image = bkg.back()
# bkg_image = np.array(bkg) # equivalent to above
# show the background
plt.imshow(bkg_image, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()

# evaluate the background noise as 2-d array, same size as original image
bkg_rms = bkg.rms()
# show the background noise
plt.imshow(bkg_rms, interpolation='nearest', cmap='gray', origin='lower')
plt.colorbar();
plt.show()
        
# subtract the background
data_sub = data - bkg        
objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
len(objects)

# plot background-subtracted image
fig, ax = plt.subplots()
m, s = np.mean(data_sub), np.std(data_sub)
im = ax.imshow(data_sub, interpolation='nearest', cmap='gray',
               vmin=m-s, vmax=m+s, origin='lower')

# plot an ellipse for each object
for i in range(len(objects)):
    e = Ellipse(xy=(objects['x'][i], objects['y'][i]),
                width=6*objects['a'][i],
                height=6*objects['b'][i],
                angle=objects['theta'][i] * 180. / np.pi)
    e.set_facecolor('none')
    e.set_edgecolor('red')
    ax.add_artist(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-2f22b6209e26> in <module>()
#      25
#      26 # subtract the background
# ---> 27 data_sub = data - bkg
#      28 objects = sep.extract(data_sub, 1.5, err=bkg.globalrms)
#      29 len(objects)
#
# ValueError: operands could not be broadcast together with shapes (3600,3600) (256,256)
